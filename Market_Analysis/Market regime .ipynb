# %%
import market_analysis as m_a
import trading as trading
# %load_ext autoreload
# %autoreload 2
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
dataset = ["CHRIS/CME_ES1","CHRIS/EUREX_FESX1","CHRIS/CME_NK1","CHRIS/EUREX_FMCN1","CHRIS/CME_US1","CHRIS/CME_GC2","CHRIS/CME_QG1","CHRIS/CME_CL1","CHRIS/CME_EC1"]
column = ["SP 500","Eurostoxx50","Nikkei","China","Treasury Bond","Gold","Natural Gas","Crude Oil","Euro FX"]
daily_rets,daily_prices = m_a.quandl_returns(dataset,column)
# Out:
# C:\Users\Gabriele\Desktop\Mercati 2020\market_analysis.py:28: RuntimeWarning: invalid value encountered in log
#   ret = np.log(prices) -np.log(prices.shift(1))

# %%
#dataset = ["CHRIS/CME_GC2"]
#column = ["Gold"]
#daily_rets,daily_prices = m_a.quandl_returns(dataset,column)

# %%
daily_rets.tail()
# Out:
#               SP 500 Eurostoxx50    Nikkei     China Treasury Bond      Gold  \
# Date
# 2020-07-27  0.008778   -0.000909  0.014874  0.000587     -0.002419  0.016254
# 2020-07-28 -0.005973    0.000606 -0.006855  0.007499      0.004315  0.005855
# 2020-07-29  0.012219   -0.000909  0.000665  0.009175     -0.000862  0.006381
# 2020-07-30 -0.001154   -0.032669 -0.013393 -0.011312      0.005673 -0.005152
# 2020-07-31  0.004530   -0.002824 -0.014031  0.003494     -0.000171  0.009519
#
#            Natural Gas Crude Oil   Euro FX
# Date
# 2020-07-27   -0.041790  0.007480  0.009695
# 2020-07-28    0.037356 -0.013553 -0.002340
# 2020-07-29    0.069733  0.005589  0.003530
# 2020-07-30   -0.053751 -0.033258  0.005926
# 2020-07-31   -0.016538  0.008729 -0.004060

# %%
import quandl
copper=quandl.get("CHRIS/MCX_CU1", api_key="eY51mj69BzDt2VXszsHd")

# %%
copper_prices=copper["Close"]

# %%
copper_returns= np.log(copper_prices) -np.log(copper_prices.shift(1))

# %%
daily_prices["Copper"]=copper_prices

# %%
daily_prices.tail()
# Out:
#              SP 500 Eurostoxx50   Nikkei   China Treasury Bond    Gold  \
# Date
# 2020-07-27  3232.25      3299.0  22690.0  1023.0     180.65625  1941.4
# 2020-07-28  3213.00      3301.0  22535.0  1030.7     181.43750  1952.8
# 2020-07-29  3252.50      3298.0  22550.0  1040.2     181.28125  1965.3
# 2020-07-30  3248.75      3192.0  22250.0  1028.5     182.31250  1955.2
# 2020-07-31  3263.50      3183.0  21940.0  1032.1     182.28125  1973.9
#
#            Natural Gas Crude Oil  Euro FX Copper
# Date
# 2020-07-27       1.734     41.60  1.17635    NaN
# 2020-07-28       1.800     41.04  1.17360    NaN
# 2020-07-29       1.930     41.27  1.17775    NaN
# 2020-07-30       1.829     39.92  1.18475    NaN
# 2020-07-31       1.799     40.27  1.17995    NaN

# %%
daily_rets["Copper"]=copper_returns

# %%
daily_rets.head()
# Out:
#               SP 500 Eurostoxx50    Nikkei     China Treasury Bond      Gold  \
# Date
# 2014-02-19 -0.006552   -0.000320 -0.008826  0.002656     -0.002582 -0.003024
# 2014-02-20  0.005872   -0.000962 -0.006842 -0.015145     -0.001882 -0.002730
# 2014-02-21 -0.001090    0.005120  0.016006  0.008937      0.002822  0.005074
# 2014-02-24  0.006385    0.006046  0.010419 -0.016144     -0.001880  0.010820
# 2014-02-25  0.000135    0.002218 -0.002008 -0.006349      0.005864  0.003506
#
#            Natural Gas Crude Oil   Euro FX    Copper
# Date
# 2014-02-19    0.102311  0.008555 -0.000945  0.008011
# 2014-02-20   -0.013920 -0.003782 -0.001748  0.000443
# 2014-02-21    0.011640 -0.007020  0.001748 -0.003662
# 2014-02-24   -0.119312  0.006048 -0.000655  0.000778
# 2014-02-25   -0.066242 -0.009675  0.000510 -0.008254

# %% [markdown]
# # Momentum

# %%
momentum = m_a.momentum(daily_prices[-20:])

# %%
momentum.tail(9)
# Out:
#                 SP 500 Eurostoxx50      Nikkei       China Treasury Bond  \
# Date
# 2020-07-21  100.986178  100.681481   99.236475  100.946611    100.312989
# 2020-07-22  102.222570  100.119119  100.087854  102.362282    100.225420
# 2020-07-23  100.420037  100.208395   99.339498  102.345271    100.765084
# 2020-07-24   98.728911   97.576832   97.962314   97.436386    100.607639
# 2020-07-27   99.415609   97.086521   99.758189   95.930233    100.208008
# 2020-07-28   98.392283   98.185604   98.902787   98.697692    100.449827
# 2020-07-29  100.774593   97.979798   99.955674   98.906532    100.103538
# 2020-07-30  101.396692   96.668686   99.530306  100.596635    100.672994
# 2020-07-31  100.966819   96.483783   96.694579  100.889541    100.899498
#
#                   Gold Natural Gas   Crude Oil     Euro FX Copper
# Date
# 2020-07-21  101.516894   94.206974  101.844660  101.076916    NaN
# 2020-07-22  103.587790   97.562391  102.822086  101.672153    NaN
# ...

# %% [markdown]
# # Correlation

# %%
m_a.correlation(daily_rets[-5:])

# %% [markdown]
# # Volatility

# %%
volatility= daily_rets.std()*100

# %%
m_a.rolling_volatility(daily_rets[-200:]).tail(10)
# Out:
#               SP 500 Eurostoxx50    Nikkei     China Treasury Bond      Gold  \
# Date
# 2020-07-20  0.187861    0.228846  0.119906  0.362039      0.064624  0.097916
# 2020-07-21  0.176833    0.224914  0.114363  0.362754      0.051920  0.105206
# 2020-07-22  0.176990    0.219593  0.114210  0.368082      0.051023  0.108507
# 2020-07-23  0.161086    0.182916  0.110508  0.360947      0.049005  0.112050
# 2020-07-24  0.163974    0.196328  0.110312  0.378369      0.048947  0.109910
# 2020-07-27  0.141994    0.193455  0.117426  0.376857      0.047761  0.118018
# 2020-07-28  0.140925    0.189512  0.119833  0.376571      0.049492  0.118032
# 2020-07-29  0.139397    0.189632  0.119530  0.376904      0.048380  0.115972
# 2020-07-30  0.139846    0.222115  0.127863  0.380863      0.049739  0.108444
# 2020-07-31  0.138382    0.194001  0.135048  0.367642      0.049946  0.109823
#
#            Natural Gas Crude Oil   Euro FX Copper
# Date
# 2020-07-20    0.640617  0.325212  0.056354    NaN
# ...

# %%
daily_rets.std()*np.sqrt(252)
# Out:
# SP 500           0.181037
# Eurostoxx50      0.205215
# Nikkei           0.221162
# China            0.243612
# Treasury Bond    0.105467
# Gold             0.142827
# Natural Gas      0.467877
# Crude Oil        0.503027
# Euro FX          0.081248
# Copper           0.227293
# dtype: float64

# %% [markdown]
# # Volume

# %%
volume = m_a.volume(dataset,column)

# %%
m_a.momentum(volume[-30:])
# Out:
#                  SP 500 Eurostoxx50      Nikkei        China Treasury Bond  \
# Date
# 2020-06-19          NaN         NaN         NaN          NaN           NaN
# 2020-06-22          NaN         NaN         NaN          NaN           NaN
# 2020-06-23          NaN         NaN         NaN          NaN           NaN
# 2020-06-24          NaN         NaN         NaN          NaN           NaN
# 2020-06-25  5349.679221   85.285684  143.026797   310.000000  11027.417795
# 2020-06-26   157.957960  110.817676   99.822222          inf    134.078013
# 2020-06-29   102.615460   89.732776   72.850201    11.334825    110.075928
# 2020-06-30    70.267333   88.477535   86.773197    66.541353    120.452340
# 2020-07-01    77.624472   86.213394   86.321056   241.935484    117.682320
# 2020-07-02    70.438356  129.581839  109.652716   240.531561     93.260755
# 2020-07-06    79.168764  107.402060   77.276682   649.342105     78.929846
# ...
